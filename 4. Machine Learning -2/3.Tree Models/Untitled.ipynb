# %% [markdown]
# #### Decision Tree
#
# A **decision tree**, as the term suggests, uses a tree-like model to make predictions. It resembles an upside-down tree and uses a similar process that you do to make decisions in real life, i.e., by asking a series of questions to arrive at a decision.
#
# ![image.png](attachment:image.png)

# %%
1. Fix outlier by replacing lower limit and upper lmiit rather than dropping columns - done
2. Change label encoding values for poor,good,very good - 1,3,4 to differentiate  - done
3. Categorize columns with lot of cateogrical values - to check distributition and recategorize - mssclass and neighbourhood
4. Feature engineering on HouseStyle - done
Fix Garage Area by creating Garage Age - done
